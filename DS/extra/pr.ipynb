# %%
import numpy as np # linear algebra
import pandas as pd # data processing
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
amd_arc_df = pd.read_csv('/home/abhi/Documents/DataSets/processor_kaggle/amd_archive_processors.csv')
amd_df = pd.read_csv('/home/abhi/Documents/DataSets/processor_kaggle/amd_processors.csv')
intel_ark_df = pd.read_csv('/home/abhi/Documents/DataSets/processor_kaggle/intel_ark_processors.csv')
intel_df = pd.read_csv('/home/abhi/Documents/DataSets/processor_kaggle/intel_processors.csv')
cpu_benchmark = pd.read_csv('/home/abhi/Documents/DataSets/processor_kaggle/cpu_benchmarks.csv')
windows11_supported_intel = pd.read_csv('/home/abhi/Documents/DataSets/processor_kaggle/Windows11_supported_intel_processors.csv')

# %%
amd_arc_df.head()
# Out:
#    id                   name  base_frequency  tdp  max_temp  \
# 0   1  AMD Athlon II X2 210e            2600   45      71.0
# 1   2  AMD Athlon II X2 270u            2000   25      81.0
# 2   3    AMD Athlon X2 6000+            3000   89      70.0
# 3   4     AMD Athlon X2 7850            2800   95      73.0
# 4   5     AMD Athlon X2 7450            2400   95      73.0
#
#                                                  url socket      product_line  \
# 0  https://web.archive.org/web/20131123023118/htt...    AM3  AMD Athlon II X2
# 1  https://web.archive.org/web/20131123220405/htt...    AM3  AMD Athlon II X2
# 2  https://web.archive.org/web/20131123023038/htt...    AM2     AMD Athlon X2
# 3  https://web.archive.org/web/20131123023033/htt...   AM2+     AMD Athlon X2
# 4  https://web.archive.org/web/20131123021445/htt...   AM2+     AMD Athlon X2
#
#    lithography       opn_tray        opn_pib revision  cache_l1  cache_l2  \
# ...

# %%
amd_arc_df.shape
# Out:
# (496, 16)

# %%
amd_df.shape
# Out:
# (538, 20)

# %%
amd_df.head()
# Out:
#    id  cores  threads                         name launch_date  lithography  \
# 0   1   16.0     32.0            AMD Ryzen 9 5950X  2020-11-05          7.0
# 1   2   12.0     24.0            AMD Ryzen 9 5900X  2020-11-05          7.0
# 2   3   12.0     24.0  AMD Ryzen 9 5900 (OEM Only)  2021-01-12          7.0
# 3   4    8.0     16.0            AMD Ryzen 7 5800X  2020-11-05          7.0
# 4   5    8.0     16.0  AMD Ryzen 7 5800 (OEM Only)  2021-01-12          7.0
#
#    base_frequency  turbo_frequency  cache_l1  cache_l2  cache_l3    tdp  \
# 0            3400           4900.0       NaN    8192.0   65536.0  105.0
# 1            3700           4800.0       NaN    6144.0   65536.0  105.0
# 2            3000           4700.0       NaN    6144.0   65536.0   65.0
# 3            3800           4700.0       NaN    4096.0   32768.0  105.0
# 4            3400           4600.0       NaN    4096.0   32768.0   65.0
#
#                      product_line socket memory_type  \
# ...

# %%
intel_ark_df.shape
# Out:
# (2877, 25)

# %%
intel_ark_df.head()
# Out:
#    id  cores  threads                name processor_number launch_date  \
# 0   1    4.0      8.0  Intel Itanium 9750             9750  2017-05-01
# 1   2    8.0     16.0  Intel Itanium 9760             9760  2017-05-01
# 2   3    4.0      8.0  Intel Itanium 9720             9720  2017-05-01
# 3   4    8.0     16.0  Intel Itanium 9740             9740  2017-05-01
# 4   5    4.0      8.0  Intel Itanium 9520             9520  2012-11-01
#
#    lithography  bus_speed  base_frequency  turbo_frequency  ...  product_line  \
# 0         32.0        6.4          2530.0              NaN  ...           NaN
# 1         32.0        6.4          2660.0              NaN  ...           NaN
# 2         32.0        6.4          1730.0              NaN  ...           NaN
# 3         32.0        6.4          2130.0              NaN  ...           NaN
# 4         32.0        6.4          1730.0              NaN  ...           NaN
#
# ...

# %%
intel_df.shape
# Out:
# (1098, 26)

# %%
intel_df.head()
# Out:
#    id  cores  threads                 name processor_number launch_date  \
# 0   1      2      2.0     Intel Atom C2338            C2338  2013-08-01
# 1   2      2      2.0     Intel Atom C2350            C2350  2013-08-01
# 2   3      2      2.0     Intel Atom C2358            C2358  2013-08-01
# 3   4      4      4.0     Intel Atom C2518            C2518  2013-08-01
# 4   5      4      8.0  Intel Core i7-8709G         i7-8709G  2018-02-01
#
#    lithography  bus_speed  base_frequency  turbo_frequency  ...     socket  \
# 0         22.0        NaN          1700.0           2000.0  ...  FCBGA1283
# 1         22.0        NaN          1700.0           2000.0  ...  FCBGA1283
# 2         22.0        NaN          1700.0           2000.0  ...  FCBGA1283
# 3         22.0        NaN          1700.0              NaN  ...  FCBGA1283
# 4         14.0        8.0          3100.0           4100.0  ...    BGA2270
#
#        memory_type                                                url  \
# ...
