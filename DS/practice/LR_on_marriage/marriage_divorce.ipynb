# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_column', 100)

# %%
# import pycaret

# %%
df = pd.read_csv('Marriage_Divorce_DB.csv')

# %%
df.shape
# Out:
# (100, 31)

# %%
df.sample(5)
# Out:
#      Age Gap  Education  Economic Similarity  Social Similarities  \
# 98  3.487983   1.658356            74.237358            41.293409
# 56  0.758385   4.871297            30.093105            69.085606
# 77  0.188714   1.346946            53.189529            71.348270
# 1   3.355384   2.957842            82.138120            48.656031
# 99  5.818757   3.087757            56.908983            41.398349
#
#     Cultural Similarities  Social Gap  Common Interests  \
# 98              12.489656   94.018496         76.700340
# 56              18.366468   90.097639         72.670288
# 77              26.852495   87.321643         66.754206
# 1               30.188517   54.114612         57.020971
# 99              35.715356   90.396363         63.087658
#
#     Religion Compatibility  No of Children from Previous Marriage  \
# 98                7.633928                               3.089036
# 56               38.869473                               4.726001
# ...

# %%
df.columns = [sub.replace(' ', '_') for sub in df.columns]

# %%
df
# Out:
#      Age_Gap  Education  Economic_Similarity  Social_Similarities  \
# 0   0.111633   1.915111            10.998678            76.456065
# 1   3.355384   2.957842            82.138120            48.656031
# 2   6.527365   2.772463            26.337826            59.356238
# 3   5.203075   1.729242            66.956033             5.472612
# 4   6.864962   4.370290            76.245035            26.797234
# ..       ...        ...                  ...                  ...
# 95  6.962987   4.290912             8.386214            62.291307
# 96  0.782445   3.134205            59.812318            65.977429
# 97  4.181422   1.213900            36.880983            66.255955
# 98  3.487983   1.658356            74.237358            41.293409
# 99  5.818757   3.087757            56.908983            41.398349
#
#     Cultural_Similarities  Social_Gap  Common_Interests  \
# 0               47.847460   50.317656         88.099898
# 1               30.188517   54.114612         57.020971
# ...

# %%
# df.info()

# %%
# df.describe().T

# %%
# df['Divorce Probability'].unique()

# %%
# df.corr()

# %%
x = df.iloc[:, 0:].drop(['Divorce Probability'], axis=1)
y = df["Divorce Probability"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit the scaler into the train set, It will learn the perameters 
scaler.fit(x_train)

# Transform x_train and x_test
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# scaler.mean_
# Out:
# array([ 5.10566824,  2.85463243, 57.85781951, 55.42627927, 46.64074261,
#        53.48810678, 74.36781578, 49.94399359,  2.9325658 , 48.82147591,
#         1.49483189, 54.32779324, 51.008454  ,  5.77387454, 59.43252801,
#        67.96656742, 73.71651202, 57.26596624, 40.52557376,  2.77044673,
#        24.46362263,  3.00039871, 62.26925474, 50.9727742 , 54.32071798,
#        71.06147299,  5.03559122,  5.29435274,  5.51509207, 28.99064345])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns= x_test.columns)

# %%
# data=x_train['Education']
# sm.qqplot(data,line='45',fit=True,dist=stats.norm)
# plt.show()
# sns.displot(data, kde=True)

# plt.show()

# %%
# colms = x_train.columns
# for i in colms:
#     data=x_train[i]
#     sm.qqplot(data,line='45',fit=True,dist=stats.norm)
#     plt.show()

# %%
from statsmodels.formula.api import ols

print(ols('Divorce_Probability~Age_Gap', data = df).fit().summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Divorce_Probability   R-squared:                       0.009
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                    0.9318
# Date:                 Wed, 24 Aug 2022   Prob (F-statistic):              0.337
# Time:                         00:48:31   Log-Likelihood:                -83.466
# No. Observations:                  100   AIC:                             170.9
# Df Residuals:                       98   BIC:                             176.1
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9600      0.125     15.737      0.000       1.713       2.207
# ...

# %%
print(ols('Divorce_Probability~Education', data = df).fit().summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Divorce_Probability   R-squared:                       0.101
# Model:                             OLS   Adj. R-squared:                  0.092
# Method:                  Least Squares   F-statistic:                     11.01
# Date:                 Wed, 24 Aug 2022   Prob (F-statistic):            0.00128
# Time:                         00:48:48   Log-Likelihood:                -78.617
# No. Observations:                  100   AIC:                             161.2
# Df Residuals:                       98   BIC:                             166.4
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.5401      0.152     16.677      0.000       2.238       2.842
# ...

# %%
print(ols('Divorce_Probability~Love', data = df).fit().summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Divorce_Probability   R-squared:                       0.010
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                    0.9441
# Date:                 Wed, 24 Aug 2022   Prob (F-statistic):              0.334
# Time:                         00:48:53   Log-Likelihood:                -83.459
# No. Observations:                  100   AIC:                             170.9
# Df Residuals:                       98   BIC:                             176.1
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8940      0.187     10.129      0.000       1.523       2.265
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
lr.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', lr.coef_)
# Out:
# Coefficients:  [ 0.10799125 -0.22381716  0.00311698  0.03268119  0.02509793  0.11904163
#  -0.10294994 -0.07699602 -0.01352106 -0.11930752  0.07907211  0.00307781
#   0.05863634  0.07727004  0.11050683  0.05471721  0.06059514 -0.07006211
#   0.00046752 -0.00092205 -0.01563532 -0.04694472  0.14588746  0.00800074
#  -0.19152599  0.02156948  0.06292067  0.07981801  0.05179296 -0.06900663]

# %%
print('Variance score: {}'.format(lr.score(x_test_scaled, y_test)))
# Out:
# Variance score: -0.9309816113832219

# %%
# lr = LinearRegression()
lr.score(x_test_scaled, y_test)
# Out:
# -0.9309816113832219
