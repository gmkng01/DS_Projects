# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# import geopandas as gpd
plt.style.use("ggplot")  #using style ggplot
# from sklearn.model_selection import train_test_split
pd.set_option('display.max_rows', 1000)
# from datetime import date
import warnings
warnings.filterwarnings('ignore')
# import statsmodels.api as sm
# import scipy.stats as stats

# %%
df = pd.read_csv('/home/abhishek/Documents/Fish/winequality-red.csv')

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# df.Species.unique()
# df.Species.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/abhishek/Documents/Fish/LR-on_Wine.ipynb Cell 6' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/abhishek/Documents/Fish/LR-on_Wine.ipynb#ch0000005?line=0'>1</a> # df.Species.unique()
# ----> <a href='vscode-notebook-cell:/home/abhishek/Documents/Fish/LR-on_Wine.ipynb#ch0000005?line=1'>2</a> df.Species.value_counts()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5568'>5569</a>     name not in self._internal_names_set
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5569'>5570</a>     and name not in self._metadata
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5570'>5571</a>     and name not in self._accessors
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5571'>5572</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5572'>5573</a> ):
#    <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5573'>5574</a>     return self[name]
# -> <a href='file:///home/abhishek/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5574'>5575</a> return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Species'

# %%
# pd.crosstab(df.Species,df.Height,margins=True).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_49715_row0_col0, #T_49715_row0_col1, #T_49715_row0_col2, #T_49715_row0_col3, #T_49715_row0_col4, #T_49715_row0_col5, #T_49715_row0_col6, #T_49715_row0_col7, #T_49715_row0_col8, #T_49715_row0_col9, #T_49715_row0_col10, #T_49715_row0_col11, #T_49715_row0_col12, #T_49715_row0_col13, #T_49715_row0_col14, #T_49715_row0_col15, #T_49715_row0_col16, #T_49715_row0_col17, #T_49715_row0_col18, #T_49715_row0_col19, #T_49715_row0_col20, #T_49715_row0_col21, #T_49715_row0_col22, #T_49715_row0_col23, #T_49715_row0_col24, #T_49715_row0_col25, #T_49715_row0_col26, #T_49715_row0_col27, #T_49715_row0_col28, #T_49715_row0_col29, #T_49715_row0_col30, #T_49715_row0_col31, #T_49715_row0_col32, #T_49715_row0_col33, #T_49715_row0_col34, #T_49715_row0_col35, #T_49715_row0_col36, #T_49715_row0_col37, #T_49715_row0_col38, #T_49715_row0_col39, #T_49715_row0_col40, #T_49715_row0_col41, #T_49715_row0_col42, #T_49715_row0_col43, #T_49715_row0_col44, #T_49715_row0_col45, #T_49715_row0_col46, #T_49715_row0_col47, #T_49715_row0_col48, #T_49715_row0_col49, #T_49715_row0_col50, #T_49715_row0_col51, #T_49715_row0_col52, #T_49715_row0_col53, #T_49715_row0_col54, #T_49715_row0_col55, #T_49715_row0_col56, #T_49715_row0_col57, #T_49715_row0_col58, #T_49715_row0_col59, #T_49715_row0_col60, #T_49715_row0_col